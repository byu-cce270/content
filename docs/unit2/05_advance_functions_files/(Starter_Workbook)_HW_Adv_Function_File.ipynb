# %% [markdown]
# <a href="https://colab.research.google.com/github/byu-cce270/content/blob/main/docs/unit2/05_advance_functions_files/(Starter_Workbook)_HW_Adv_Function_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Part 1: Define your functions here
#
# Write four functions:
# - `cantilever()` and `simply_supported()` — each takes `load_type`, `load`, `L`, `E`, and `I`, and returns the maximum deflection and maximum moment (use IF/ELIF inside to pick the right formula for the load type).
# - `inertia()` — takes the base `b` and height `h` and returns the moment of inertia.
# - `sigma_max()` — takes the maximum moment `M`, `y` (half the beam height), and `I`, and returns the maximum bending stress.

# %% [markdown]
# ### Part 2: Read the beam data, run your functions, and write the results
#
# In the code block below:
# 1. Open `beam_inputs.csv` using a context manager, skipping the header row. For each line, extract the values and convert them to the correct data types.
# 2. Use your functions to calculate the maximum deflection and maximum bending stress for each beam.
# 3. Append each result to a text file called `beam_results.txt`, formatted as:
#    `Beam ID: XXXX, Maximum Deflection: Y.YYY inches, Maximum Bending Stress: ZZZ.ZZ psi`
#
# **Note:** Upload `beam_inputs.csv` to your Colab session (or mount your Drive) so the file can be opened.
