# %% [markdown]
# <a href="https://colab.research.google.com/github/byu-cce270/content/blob/main/docs/unit2/06_classes/(Starter_Workbook)_Class_Intro_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review of Reading
# Here is the "Dog" class from the reading for discussion and review.

# %%
class Dog:
  """A simple attempt to model a dog."""
  def __init__(self, name, age):
        """Initialize name and age attributes."""
        self.name = name
        self.age = age
  def sit(self):
        """Simulate a dog sitting in response to a command."""
        print(f"{self.name} is now sitting.")
  def roll_over(self):
        """Simulate rolling over in response to a command."""
        print(f"{self.name} rolled over!")

# %% [markdown]
# # Discussion Quesionts
# *   Why is "Dog" capitalized?
# *   What is the "init" method?
# *   Why two __ before and after?
# *   What it the "self" varible, why is it needed?

# %%
my_dog = Dog('Willie', 6)
your_dog = Dog('Lucy', 3)

print(f"My dog's name is {my_dog.name}.")
print(f"My dog is {my_dog.age} years old.")
my_dog.sit()

print(f"\nYour dog's name is {your_dog.name}.")  # note the \n in the print statement
print(f"Your dog is {your_dog.age} years old.")
your_dog.sit()

# %% [markdown]
# # Discussion Questions
# *  Why isn't "my_dog" capitalized?
# *  What does Line 1 do and what is that called?
# *  What is the "." or "dot" notation for objects?
# *  What is the different between dog.name and dog.sit()?
# *  Why does on have () and one not?

# %%
# %%writefile car.py
# write out the class to a file for import (need to save to your computer)

class Car:
    """A simple attempt to represent a car."""

    def __init__(self, make, model, year):
        """Initialize attributes to describe a car."""
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

    def get_descriptive_name(self):
        """Return a neatly formatted descriptive name."""
        long_name = f"{self.year} {self.make} {self.model}"
        return long_name.title()

    def read_odometer(self):
        """Print a statement showing the car's mileage."""
        print(f"This car has {self.odometer_reading} miles on it.")

    def update_odometer(self, mileage):
        """
        Set the odometer reading to the given value.
        Reject the change if it attempts to roll the odometer back.
        """
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("You can't roll back an odometer!")

    def increment_odometer(self, miles):
        """Add the given amount to the odometer reading."""
        self.odometer_reading += miles

# %%
my_used_car = Car('subaru', 'outback', 2019)
print(my_used_car.get_descriptive_name())

my_used_car.odometer_reading = 235
my_used_car.read_odometer()

my_used_car.update_odometer(23500)
my_used_car.read_odometer()

my_used_car.increment_odometer(100)
my_used_car.read_odometer()

my_used_car.update_odometer(2350)

# %% [markdown]
# # Classes, Objects, varibiles
# * Discuss classes and objects
# * Class has template - objects are specific
# * Each object can have varialbles assocaited with it
# * Many ways to "update" or "change" varibles

# %%
# %%writefile electric_car.py
# write out the class to a file for import (need to save to your computer)

from car import Car  # needed for inheritance demonstration

class Battery:
    """A simple attempt to model a battery for an electric car."""

    def __init__(self, battery_size=40):
        """Initialize the battery's attributes."""
        self.battery_size = battery_size

    def describe_battery(self):
        """Print a statement describing the battery size."""
        print(f"This car has a {self.battery_size}-kWh battery.")

    def get_range(self):
        """Print a statement about the range this battery provides."""
        if self.battery_size == 40:
            range = 150
        elif self.battery_size == 65:
            range = 225

        print(f"This car can go about {range} miles on a full charge.")


class ElectricCar(Car):
    """Represent aspects of a car, specific to electric vehicles."""

    def __init__(self, make, model, year):
        """
        Initialize attributes of the parent class.
        Then initialize attributes specific to an electric car.
        """
        super().__init__(make, model, year)
        self.battery = Battery()
# Out:
# Overwriting electric_car.py

# %%
my_leaf = ElectricCar('nissan', 'leaf', 2024)
print(my_leaf.get_descriptive_name())
my_leaf.battery.describe_battery()
my_leaf.battery.get_range()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2407793289.py in <cell line: 0>()
# ----> 1 my_leaf = ElectricCar('nissan', 'leaf', 2024)
#       2 print(my_leaf.get_descriptive_name())
#       3 my_leaf.battery.describe_battery()
#       4 my_leaf.battery.get_range()
#
# NameError: name 'ElectricCar' is not defined

# %%
# Use "Restart Session" from run menu to "forget" classes but not erase files

from car import Car
from electric_car import ElectricCar


my_mustang = Car('ford', 'mustang', 2024)
print(my_mustang.get_descriptive_name())

my_leaf = ElectricCar('nissan', 'leaf', 2024)
print(my_leaf.get_descriptive_name())
# Out:
# 2024 Ford Mustang
# 2024 Nissan Leaf

# %% [markdown]
# # Inheritance
# - What is inheritance?
# - Why would you use it?
# - How do you "inherit" structure from a class?

# %% [markdown]
# # Exercise 1 - Student Class
#
# In the first exercise, we will practice writing the pattern for a class in different steps.

# %% [markdown]
# ## Step 1
#
# Below in Code Block 1, you will define the class `Student`. The class should have the following attributes:
#
# - first name
# - last name
# - major
# - year, the default year should be "Freshman", so this isn't required when an object is instantiated.
# - gpa, you should not need to put a GPA in when you instantiate an object
# - set the default gpa to "None".
# - Create a method so any GPA scores entered are validated and between 0 and 4 (the GPA can also be 0 or 4).
# - Print a message if a score entered does not follow this validation and then set the score to None.

# %%
# @title Code Block 1

# %% [markdown]
# In the following code block, create a student and print out each attribute. When you define the student, only give it a first name, last name, and a major. We will test the defaults you set up for the year and GPA.

# %%
# @title Code Block 1 Test
# Test code for your code in Code Block 1.

# %% [markdown]
# ## Step 2
#
# In Code Block 2, create a new class called `describe_Student` by copying your 'Student' class from Code Block 1.
#
# Add a `describe` method to your new class. It should say something like "Brandan Williamson is a Senior majoring in Civil Engineering."

# %%
# @title Code Block 2

# %% [markdown]
# In the following code block, create another student and try calling your describe method.

# %%
# @title Code Block 2 Test

# %% [markdown]
# ## Step 3
#
# In Code Block 3, create a new class called `Full_Student` by copying your `describe_Student` class from Code Block 2.
#
# Add two more methods: `update_year` and `is_honors`.
#
# -  `update_year` should update the student's year by one.
# -  `is_honors` should check to see if the student's GPA is greater than or equal to 3.5.
# -  If the student is or is not an honors student, print a message saying so.

# %%
# @title Code Block 3

# %% [markdown]
# In the following code block, create 2 more students. For these students, make sure one has a GPA of 3.5 or higher and the other is lower. The year in school doesn't matter.
#
# Test your 'update_year' method by calling your 'describe' method for one of the new students. Then run the 'update_year' method and call your 'describe' method again.
#
# Now test your 'is_honors' method by simply just calling the method for each student.

# %%
# @title Code Block 3 Test

# Create the 2 new students



# 'update_year' test



# 'is_honors' test

# %% [markdown]
# # Exercise 2 & 3 - Independent Practice
#
# Build the following classes on your own. Use the same pattern as the Student example.

# %% [markdown]
# ## Vehicle Class
# (Hint: this is not the same as the one from the book)
#
# In Code Block 4, create `Vehicle`:
# - `make`, `model`, `year`, `odometer` (start at 0)
# - `drive(miles)` adds miles to odometer
#
# Also, create `ConstructionVehicle` (inherits from `Vehicle`):
# - add `equipment_type` and `engine_hours` (start at 0)
# - `run(hours)` adds to engine_hours
# - `needs_service()` if miles or hours exceed a threshold you choose

# %%
# @title Code Block 4

# %% [markdown]
# Test your 'ConstructionVehicle' class below.

# %%
# @title Code Block 4 Test

# %% [markdown]
# ## ConcreteBatch Class
#
# In Code Block 5, create `ConcreteBatch` with:
# - `cement_kg`, `water_kg`, `aggregate_kg`
# - `water_cement_ratio()` returns water_kg / cement_kg
# - `total_mass()` returns sum
# - `summary()` prints the mix + w/c ratio
# - validate: cement can’t be 0; all masses > 0
# - `meets_wc_limit(limit)` (example limit = 0.50)

# %%
# @title Code Block 5

# %% [markdown]
# Test you 'ConcreteBatch' class below. You can use the following values
# - Cement = 400.0 kg
# - Water = 180.0 kg
# - Aggregate = 1200.0

# %%
# @title Code Block 5 Test

# %% [markdown]
# # Bonus Exercise - BankAccount
#
# If time permits or you still want more practice, create `BankAccount` in code block 6 with:
# - `owner`, `balance` (default 0)
# - `deposit(amount)`
# - `withdraw(amount)` (prevent overdraft: print a message)
# - transaction history list
# - `__str__()` summary

# %%
# @title Code Block 6

# %% [markdown]
# Test your 'BankAccount' class below.

# %%
# @title Code Block 6 Test
