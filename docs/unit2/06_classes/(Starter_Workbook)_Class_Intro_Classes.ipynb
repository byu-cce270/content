# %% [markdown]
# <a href="https://colab.research.google.com/github/byu-cce270/content/blob/main/docs/unit2/06_classes/(Starter_Workbook)_Class_Intro_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exersise 1 - Student Class
#
# In the first exersise, we will pratice writing the pattern for a class in different sets.

# %% [markdown]
# ## Step 1
#
# Below in Code Block 1, you will define the class 'Student'. The class should have the following attributes:
#
# - first name
# - last name
# - major
# - year, the default year should be "Freshman"
# - gpa, you should be able to not put a GPA in. Also set it up so any GPA scores put in are validated and between 0 and 4 (the GPA and also be 0 or 4). Print a message if a score inputed does not follow this validation and then set the score to None.

# %%
# @title Code Block 1

# %% [markdown]
# In the following code block, create a student and print out each attribue. When you define the student, only give it a first name, last name, and a major. We will test the defaluts you set up for the year and GPA.

# %%
# @title Code Block 1 Test
# Test code for your code in Code Block 1.

# %% [markdown]
# ## Step 2
#
# In Code Block 2, create a new classe called 'describe_Student' by copying your 'Student' class from Code Block 1.
#
# Add a 'describe' method to your new class. It should say something like "Brandan Williamson is a Senior majoring in Civil Engineering."

# %%
# @title Code Block 2

# %% [markdown]
# In the following code block, create another student and try calling your describe method.

# %%
# @title Code Block 2 Test

# %% [markdown]
# ## Step 3
#
# In Code Block 3, create a new classe called 'Full_Student' by copying your 'describe_Student' class from Code Block 2.
#
# Add two more methods: 'update_year' and 'is_honors'.
#
# 'update_year' should update the student's year.
# 'is_honors' should check to see if the student's GPA is greater than or equal to 3.5. If the student is or is not a honor student, print a message saying so.

# %%
# @title Code Block 3

# %% [markdown]
# In the following code block, create 2 more students. For these students, make sure one have a GPA of 3.5 or higher and the other is lower. The year in school doesn't matter.
#
# Test your 'update_year' method by calling your 'describe' method for one of then new students. Then run the 'update_year' method and call your 'describe' method again.
#
# Now test your 'is_honors' method by simply just calling the method for each student.

# %%
# @title Code Block 3 Test

# Create the 2 new students



# 'update_year' test



# 'is_honors' test

# %% [markdown]
# # Exersise 2 & 3 - Independent Practice
#
# Build the following classes on your own. Use the same pattern as the Student example.

# %% [markdown]
# ## Vehicle Class
#
# In Code Block 4, create `Vehicle`:
# - `make`, `model`, `year`, `odometer` (start at 0)
# - `drive(miles)` adds miles to odometer
#
# Also, create `ConstructionVehicle` (inherits from `Vehicle`):
# - add `equipment_type` and `engine_hours` (start at 0)
# - `run(hours)` adds to engine_hours
# - `needs_service()` if miles or hours exceed a threshold you choose

# %%
# @title Code Block 4

# %% [markdown]
# Test you 'ConstuctionVehicle' class below.

# %%
# @title Code Block 4 Test

# %% [markdown]
# ## ConcreteBatch Class
#
# In Code Block 5, create `ConcreteBatch` with:
# - `cement_kg`, `water_kg`, `aggregate_kg`
# - `water_cement_ratio()` returns water_kg / cement_kg
# - `total_mass()` returns sum
# - `summary()` prints the mix + w/c ratio
# - validate: cement can’t be 0; all masses > 0
# - `meets_wc_limit(limit)` (example limit = 0.50)

# %%
# @title Code Block 5

# %% [markdown]
# Test you 'ConcreteBatch' class below.

# %%
# @title Code Block 5 Test

# %% [markdown]
# # Bonus Exersise - BankAccount
#
# If time permits or you still want more pratice, create `BankAccount` in code block 6 with:
# - `owner`, `balance` (default 0)
# - `deposit(amount)`
# - `withdraw(amount)` (prevent overdraft: print a message)
# - transaction history list
# - `__str__()` summary

# %%
# @title Code Block 6

# %% [markdown]
# Test you 'BankAccount' class below.

# %%
# @title Code Block 6 Test
