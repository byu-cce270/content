# %% [markdown]
# <a href="https://colab.research.google.com/github/byu-cce270/content/blob/main/docs/unit2/06_classes/(Starter_Workbook)_HW_Intro_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1 - Material Class
#
# Create a `Material` class that tracks construction materials. See the homework instructions for full details.
#
# Your class should have:
# - `__init__` with: `name`, `unit_cost`, `unit`, `quantity` (default 0) — with validation
# - `total_cost()` — returns unit_cost * quantity
# - `add_quantity(amount)` — adds to quantity (validate > 0)
# - `use_quantity(amount)` — subtracts from quantity (validate enough available)
# - `__str__()` — returns a formatted string like: `Concrete: 50 cubic yards @ $125.00/cubic yard = $6,250.00`

# %%
# @title Code Block 1 - Material Class
# Define your Material class here

# %% [markdown]
# **Test your Material class below.** Create a material, print it, add quantity, use quantity, and try to use more than is available.

# %%
# @title Code Block 1 Test
# Test your Material class here

# %% [markdown]
# ---
# # Part 2 - ConstructionProject Class
#
# Create a `ConstructionProject` class that manages a construction project using `Material` objects from Part 1. See the homework instructions for full details.
#
# Your class should have:
# - `__init__` with: `project_name`, `budget`, `labor_rate` — also initialize `materials` (empty list) and `hours_worked` (0)
# - `add_material(material)` — appends a Material object to the list
# - `log_hours(hours)` — adds hours (validate > 0)
# - `total_material_cost()` — loops through materials and sums their total_cost()
# - `total_labor_cost()` — returns labor_rate * hours_worked
# - `total_project_cost()` — returns material cost + labor cost
# - `is_under_budget()` — returns True/False
# - `summary()` — prints a formatted project summary

# %%
# @title Code Block 2 - ConstructionProject Class
# Define your ConstructionProject class here

# %% [markdown]
# **Test your ConstructionProject class below.** Create materials (concrete, rebar, lumber), create a project, add materials, log hours, and print the summary. Use the test data from the homework instructions.

# %%
# @title Code Block 2 Test
# Test your ConstructionProject class here

# %% [markdown]
# ---
# # Part 3 - RoadProject (Inheritance)
#
# Create a `RoadProject` class that **inherits** from `ConstructionProject`. See the homework instructions for full details.
#
# Your class should have:
# - `__init__` with: `project_name`, `budget`, `labor_rate`, `length_miles`, `num_lanes` — use `super().__init__()` for the first three
# - `cost_per_mile()` — returns total project cost / length_miles
# - `cost_per_lane_mile()` — returns cost_per_mile() / num_lanes
# - Override `summary()` — include road length, lanes, cost per mile, and cost per lane-mile

# %%
# @title Code Block 3 - RoadProject Class
# Define your RoadProject class here

# %% [markdown]
# **Test your RoadProject class below.** Create materials (asphalt, gravel, rebar), create a road project, add materials, log hours, and print the summary. Use the test data from the homework instructions.

# %%
# @title Code Block 3 Test
# Test your RoadProject class here
