# %% [markdown]
# <a href="https://colab.research.google.com/github/byu-cce270/content/blob/main/docs/unit3/02_intro_to_pandas/(Starter_Notebook)_Pre_Intro_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Take the following code. Transform it into a pandas dataframe and show the resulting dataframe. Turn it is with the quiz.
#
# Hint: You can create a dictionary, and then create a dataframe from a dictionary.
# [Pandas Dataframes](https://www.w3schools.com/python/pandas/pandas_dataframes.asp)
#
# It should looks something like this:
#
#
# ![image.png](data:image/png;base64,...)
